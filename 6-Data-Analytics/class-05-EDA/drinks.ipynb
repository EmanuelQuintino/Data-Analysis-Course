# %%
import pandas as pd

# %%
dataframe = pd.read_csv("./datasets/drinks.csv")

# %%
dataframe.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
dataframe.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# dtype: int64

# %%
dataframe.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
dataframe[dataframe["country"] == "Brazil"]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 23  Brazil            245              145             16
#
#     total_litres_of_pure_alcohol
# 23                           7.2

# %%
dataframe.query("200 < beer_servings < 300")
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 3               Andorra            245              138            312
# 4                Angola            217               57             45
# 8             Australia            261               72            212
# 9               Austria            279               75            191
# 16              Belgium            295               84            212
# 17               Belize            263              114              8
# 23               Brazil            245              145             16
# 25             Bulgaria            231              252             94
# 32               Canada            240              122            100
# 42              Croatia            230               87            254
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# ...

# %%
wine = dataframe.query("wine_servings > 250")
wine
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 3        Andorra            245              138            312
# 42       Croatia            230               87            254
# 48       Denmark            224               81            278
# 61        France            127              151            370
# 99    Luxembourg            236              133            271
# 136     Portugal            194               67            339
# 156     Slovenia            270               51            276
# 166  Switzerland            185              100            280
#
#      total_litres_of_pure_alcohol
# 3                            12.4
# 42                           10.2
# 48                           10.4
# 61                           11.8
# 99                           11.4
# 136                          11.0
# 156                          10.6
# 166                          10.2

# %%
wine.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count       8.000000         8.000000       8.000000
# mean      213.875000       101.000000     297.500000
# std        44.315226        36.146527      39.518531
# min       127.000000        51.000000     254.000000
# 25%       191.750000        77.500000     274.750000
# 50%       227.000000        93.500000     279.000000
# 75%       238.250000       134.250000     318.750000
# max       270.000000       151.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                      8.000000
# mean                      11.000000
# std                        0.807111
# min                       10.200000
# 25%                       10.350000
# 50%                       10.800000
# 75%                       11.500000
# max                       12.400000
